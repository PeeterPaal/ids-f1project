# %% [markdown]
# # F1 Analysis - Introduction to Data Sciences project

# %% [markdown]
# ## Importing libraries

# %%
# Already added some that we most probably will use
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
# Add more whenever needed
# ...
from datetime import datetime

# %% [markdown]
# ## Reading in the data

# %% [markdown]
# The data consists of most of the freely available Formula 1 data from 1950 to 2018. <br>
# Link: http://ergast.com/mrd/

# %%
circuits = pd.read_csv('./f1db_csv/circuits.csv', header=None)
constructor_results = pd.read_csv('./f1db_csv/constructor_results.csv', header=None)
constructor_standings = pd.read_csv('./f1db_csv/constructor_standings.csv', header=None)
constructors = pd.read_csv('./f1db_csv/constructors.csv', header=None)
drivers = pd.read_csv('./f1db_csv/driver.csv', header=None)
driver_standings = pd.read_csv('./f1db_csv/driver_standings.csv', header=None)
lap_times = pd.read_csv('./f1db_csv/lap_times.csv', header=None)
pit_stops = pd.read_csv('./f1db_csv/pit_stops.csv', header=None)
qualifying = pd.read_csv('./f1db_csv/qualifying.csv', header=None)
races = pd.read_csv('./f1db_csv/races.csv', header=None)
results = pd.read_csv('./f1db_csv/results.csv', header=None)
seasons = pd.read_csv('./f1db_csv/seasons.csv', header=None)
status = pd.read_csv('./f1db_csv/status.csv', header=None)

# %% [markdown]
# ## Adding correct column names to the datasets

# %% [markdown]
# Column names are based on the column names from here: https://www.kaggle.com/cjgdev/formula-1-race-data-19502017. <br>
# Column names in our project are in snake case (snake_case).

# %%
circuits_column_names = ['circuit_id', 'circuit_ref', 'name', 'location', 'country', 'lat', 'lng', 'alt', 'url']
constructor_results_column_names = ['constructor_results_id', 'race_id', 'constructor_id', 'points', 'status']
constructor_standings_column_names = ['constructor_standings_id', 'race_id', 'constructor_id', 'points', 'position', 'position_text', 'wins']
constructors_column_names = ['constructor_id', 'constructor_ref', 'name', 'nationality', 'url']
drivers_column_names = ['driver_id', 'driver_ref', 'number', 'code', 'forename', 'surname', 'birth_date', 'nationality', 'url']
driver_standings_column_names = ['driver_standings_id', 'race_id', 'driver_id', 'points', 'position', 'position_text', 'wins']
lap_times_column_names = ['race_id', 'driver_id', 'lap', 'position', 'time', 'milliseconds']
pit_stops_column_names = ['race_id', 'driver_id', 'stop', 'lap', 'time', 'duration', 'milliseconds']
qualifying_column_names = ['qualify_id', 'race_id', 'driver_id', 'constructor_id', 'number', 'position', 'q1', 'q2', 'q3']
races_column_names = ['race_id', 'year', 'round', 'circuit_id', 'name', 'date', 'time', 'url']
results_column_names = ['result_id', 'race_id', 'driver_id', 'constructor_id', 'number', 'grid', 'position', 'position_text', 'position_order', 'points', 'laps', 'time', 'milliseconds', 'fastest_lap', 'rank', 'fastest_lap_time', 'fastest_lap_speed', 'status_id']
seasons_column_names = ['year', 'url']
status_column_names = ['status_id', 'status']

# %%
circuits.columns = circuits_column_names
constructor_results.columns = constructor_results_column_names
constructor_standings.columns = constructor_standings_column_names
constructors.columns = constructors_column_names
drivers.columns = drivers_column_names
driver_standings.columns = driver_standings_column_names
lap_times.columns = lap_times_column_names
pit_stops.columns = pit_stops_column_names
qualifying.columns = qualifying_column_names
races.columns = races_column_names
results.columns = results_column_names
seasons.columns = seasons_column_names
status.columns = status_column_names

# %% [markdown]
# ## Replacing different types of non-existent (and non-sensical) values with a universal one

# %% [markdown]
# We are using np.nan as the universal non-existent value.

# %%
datasets = [circuits, constructor_results, constructor_standings, constructors, drivers, driver_standings, lap_times, pit_stops, qualifying, races, results, seasons, status]

for data in datasets:
    for column in data.columns:
        data[column] = data[column].replace('\\N', np.nan)  # Replacing previously used non-existent value with ours
        data[column] = data[column].replace('', np.nan)  # Replacing missing values

# %% [markdown]
# ## Comparing the fastest lap times at frequent circuits during the 2004-2018 period

# %% [markdown]
# We are using the absolute fastest lap times at every track year by year (fastest lap during the race). <br>
# There are 14 such circuits. <br>
# Afterwards we shall make a 2x7 grid of the corresponding graphs.

# %%
years = [2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018]

suitable_races = []

for index, row in races.iterrows():
    year = int(row['year'])
    if (year in years):  # If the year of the race is between 2004 and 2018
        suitable_races.append([row['race_id'], row['circuit_id'], year])

circuit_year_lap = []

for race in suitable_races:
    race_id = race[0]
    race_lap_times = results.loc[results['race_id'] == race_id]['fastest_lap_time']
    lowest_race_lap_time = 10000
    for lap_time in race_lap_times:
        if (not lap_time is np.nan):
            minutes_seconds = lap_time.split(":")
            lap_time = float(int(minutes_seconds[0]) * 60 + float(minutes_seconds[1]))
            if (lap_time < lowest_race_lap_time):
                lowest_race_lap_time = lap_time
    circuit_year_lap.append([race[1], race[2], lowest_race_lap_time])

for i in circuit_year_lap:
    circuit_id = i[0]
    circuit_name = circuits.loc[circuits['circuit_id'] == circuit_id]['name']
    i[0] = circuit_name.tolist()[0]
    
df_circuit_year_lap = pd.DataFrame(circuit_year_lap)
df_circuit_year_lap.columns = ['circuit', 'year', 'fastest lap time (s)']

df_circuit_year_lap = df_circuit_year_lap.sort_values(['circuit', 'year'], ascending=True)
    

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', -1)
df_circuit_year_lap = df_circuit_year_lap.groupby('circuit').filter(lambda x : len(x)>10)
print(df_circuit_year_lap)
# Out:
#                             circuit  year  fastest lap time (s)
# 89   Albert Park Grand Prix Circuit  2004  84.125
# 70   Albert Park Grand Prix Circuit  2005  85.683
# 54   Albert Park Grand Prix Circuit  2006  86.045
# 35   Albert Park Grand Prix Circuit  2007  85.235
# 17   Albert Park Grand Prix Circuit  2008  87.418
# 0    Albert Park Grand Prix Circuit  2009  87.706
# 108  Albert Park Grand Prix Circuit  2010  88.358
# 126  Albert Park Grand Prix Circuit  2011  88.947
# 145  Albert Park Grand Prix Circuit  2012  89.187
# 165  Albert Park Grand Prix Circuit  2013  89.274
# 184  Albert Park Grand Prix Circuit  2014  92.478
# 208  Albert Park Grand Prix Circuit  2015  90.945
# 222  Albert Park Grand Prix Circuit  2016  88.997
# 243  Albert Park Grand Prix Circuit  2017  86.538
# 263  Albert Park Grand Prix Circuit  2018  85.945
# 103  Autodromo Nazionale di Monza    2004  81.046
# 84   Autodromo Nazionale di Monza    2005  81.504
# 66   Autodromo Nazionale di Monza    2006  82.559
# 47   Autodromo Nazionale di Monza    2007  82.871
# 30   Autodromo Nazionale di Monza    2008  88.047
# 12   Autodromo Nazionale di Monza    2009  84.739
# 120  Autodromo Nazionale di Monza    2010  84.139
# 138  Autodromo Nazionale di Monza    2011  86.187
# 157  Autodromo Nazionale di Monza    2012  87.239
# 176  Autodromo Nazionale di Monza    2013  85.849
# 196  Autodromo Nazionale di Monza    2014  88.004
# 214  Autodromo Nazionale di Monza    2015  86.672
# 235  Autodromo Nazionale di Monza    2016  85.340
# 255  Autodromo Nazionale di Monza    2017  83.361
# 276  Autodromo Nazionale di Monza    2018  82.497
# 106  Autódromo José Carlos Pace      2004  71.473
# 86   Autódromo José Carlos Pace      2005  72.268
# 69   Autódromo José Carlos Pace      2006  72.162
# 51   Autódromo José Carlos Pace      2007  72.445
# 34   Autódromo José Carlos Pace      2008  73.736
# 15   Autódromo José Carlos Pace      2009  73.733
# 124  Autódromo José Carlos Pace      2010  73.851
# 144  Autódromo José Carlos Pace      2011  75.324
# 164  Autódromo José Carlos Pace      2012  78.069
# 183  Autódromo José Carlos Pace      2013  75.436
# 201  Autódromo José Carlos Pace      2014  73.555
# 220  Autódromo José Carlos Pace      2015  74.832
# 241  Autódromo José Carlos Pace      2016  85.305
# 261  Autódromo José Carlos Pace      2017  71.044
# 282  Autódromo José Carlos Pace      2018  70.540
# 91   Bahrain International Circuit   2004  90.252
# 72   Bahrain International Circuit   2005  91.447
# 52   Bahrain International Circuit   2006  92.408
# 37   Bahrain International Circuit   2007  94.067
# 19   Bahrain International Circuit   2008  93.193
# 3    Bahrain International Circuit   2009  94.556
# 107  Bahrain International Circuit   2010  118.287
# 148  Bahrain International Circuit   2012  96.379
# 168  Bahrain International Circuit   2013  96.961
# 186  Bahrain International Circuit   2014  97.020
# 205  Bahrain International Circuit   2015  96.311
# 223  Bahrain International Circuit   2016  94.482
# 245  Bahrain International Circuit   2017  92.798
# 264  Bahrain International Circuit   2018  93.740
# 96   Circuit Gilles Villeneuve       2004  73.622
# 77   Circuit Gilles Villeneuve       2005  74.384
# 60   Circuit Gilles Villeneuve       2006  75.841
# 40   Circuit Gilles Villeneuve       2007  76.367
# 23   Circuit Gilles Villeneuve       2008  77.387
# 114  Circuit Gilles Villeneuve       2010  76.972
# 132  Circuit Gilles Villeneuve       2011  76.956
# 151  Circuit Gilles Villeneuve       2012  75.752
# 171  Circuit Gilles Villeneuve       2013  76.182
# 190  Circuit Gilles Villeneuve       2014  78.504
# 204  Circuit Gilles Villeneuve       2015  76.987
# 228  Circuit Gilles Villeneuve       2016  75.599
# 249  Circuit Gilles Villeneuve       2017  74.551
# 269  Circuit Gilles Villeneuve       2018  73.864
# 93   Circuit de Barcelona-Catalunya  2004  77.450
# 74   Circuit de Barcelona-Catalunya  2005  75.641
# 57   Circuit de Barcelona-Catalunya  2006  76.648
# 38   Circuit de Barcelona-Catalunya  2007  82.680
# 20   Circuit de Barcelona-Catalunya  2008  81.670
# 4    Circuit de Barcelona-Catalunya  2009  82.762
# 111  Circuit de Barcelona-Catalunya  2010  84.357
# 130  Circuit de Barcelona-Catalunya  2011  86.727
# 149  Circuit de Barcelona-Catalunya  2012  86.250
# 169  Circuit de Barcelona-Catalunya  2013  86.217
# 188  Circuit de Barcelona-Catalunya  2014  88.918
# 206  Circuit de Barcelona-Catalunya  2015  88.270
# 226  Circuit de Barcelona-Catalunya  2016  86.948
# 247  Circuit de Barcelona-Catalunya  2017  83.593
# 267  Circuit de Barcelona-Catalunya  2018  78.441
# 94   Circuit de Monaco               2004  74.439
# 75   Circuit de Monaco               2005  75.842
# 58   Circuit de Monaco               2006  75.143
# 39   Circuit de Monaco               2007  75.284
# 22   Circuit de Monaco               2008  76.689
# 5    Circuit de Monaco               2009  75.154
# 112  Circuit de Monaco               2010  75.192
# 131  Circuit de Monaco               2011  76.234
# 150  Circuit de Monaco               2012  77.296
# 170  Circuit de Monaco               2013  76.577
# 189  Circuit de Monaco               2014  78.479
# 203  Circuit de Monaco               2015  78.063
# 227  Circuit de Monaco               2016  77.939
# 248  Circuit de Monaco               2017  74.820
# 268  Circuit de Monaco               2018  74.260
# 102  Circuit de Spa-Francorchamps    2004  105.108
# 85   Circuit de Spa-Francorchamps    2005  111.453
# 48   Circuit de Spa-Francorchamps    2007  108.036
# 29   Circuit de Spa-Francorchamps    2008  107.930
# 11   Circuit de Spa-Francorchamps    2009  107.263
# 119  Circuit de Spa-Francorchamps    2010  109.069
# 137  Circuit de Spa-Francorchamps    2011  109.883
# 156  Circuit de Spa-Francorchamps    2012  112.822
# 175  Circuit de Spa-Francorchamps    2013  110.756
# 195  Circuit de Spa-Francorchamps    2014  110.511
# 213  Circuit de Spa-Francorchamps    2015  112.416
# 234  Circuit de Spa-Francorchamps    2016  111.583
# 254  Circuit de Spa-Francorchamps    2017  106.577
# 275  Circuit de Spa-Francorchamps    2018  106.286
# 101  Hungaroring                     2004  79.071
# 82   Hungaroring                     2005  81.219
# 64   Hungaroring                     2006  83.516
# 45   Hungaroring                     2007  80.047
# 27   Hungaroring                     2008  81.195
# 9    Hungaroring                     2009  81.931
# 118  Hungaroring                     2010  82.362
# 136  Hungaroring                     2011  83.415
# 155  Hungaroring                     2012  84.136
# 174  Hungaroring                     2013  84.069
# 194  Hungaroring                     2014  85.724
# 212  Hungaroring                     2015  84.821
# 232  Hungaroring                     2016  83.086
# 253  Hungaroring                     2017  80.182
# 274  Hungaroring                     2018  80.012
# 31   Marina Bay Street Circuit       2008  105.599
# 13   Marina Bay Street Circuit       2009  108.240
# 121  Marina Bay Street Circuit       2010  107.976
# 139  Marina Bay Street Circuit       2011  108.454
# 158  Marina Bay Street Circuit       2012  111.033
# 177  Marina Bay Street Circuit       2013  108.574
# 197  Marina Bay Street Circuit       2014  110.417
# 215  Marina Bay Street Circuit       2015  110.041
# 236  Marina Bay Street Circuit       2016  107.187
# 256  Marina Bay Street Circuit       2017  105.008
# 277  Marina Bay Street Circuit       2018  101.905
# 90   Sepang International Circuit    2004  94.223
# 71   Sepang International Circuit    2005  95.483
# 53   Sepang International Circuit    2006  94.803
# 36   Sepang International Circuit    2007  96.701
# 18   Sepang International Circuit    2008  95.366
# 1    Sepang International Circuit    2009  96.641
# 109  Sepang International Circuit    2010  97.054
# 127  Sepang International Circuit    2011  100.571
# 146  Sepang International Circuit    2012  100.722
# 166  Sepang International Circuit    2013  99.199
# 185  Sepang International Circuit    2014  103.066
# 209  Sepang International Circuit    2015  102.062
# 237  Sepang International Circuit    2016  96.424
# 257  Sepang International Circuit    2017  94.080
# 104  Shanghai International Circuit  2004  92.238
# 88   Shanghai International Circuit  2005  93.242
# 67   Shanghai International Circuit  2006  97.586
# 50   Shanghai International Circuit  2007  97.454
# 33   Shanghai International Circuit  2008  96.325
# 2    Shanghai International Circuit  2009  112.592
# 110  Shanghai International Circuit  2010  102.061
# 128  Shanghai International Circuit  2011  98.993
# 147  Shanghai International Circuit  2012  99.960
# 167  Shanghai International Circuit  2013  96.808
# 187  Shanghai International Circuit  2014  100.402
# 207  Shanghai International Circuit  2015  102.208
# 224  Shanghai International Circuit  2016  99.824
# 244  Shanghai International Circuit  2017  95.378
# 265  Shanghai International Circuit  2018  95.785
# 99   Silverstone Circuit             2004  78.739
# 80   Silverstone Circuit             2005  80.502
# 59   Silverstone Circuit             2006  81.599
# 43   Silverstone Circuit             2007  80.638
# 25   Silverstone Circuit             2008  92.150
# 7    Silverstone Circuit             2009  80.735
# 116  Silverstone Circuit             2010  90.874
# 134  Silverstone Circuit             2011  94.908
# 153  Silverstone Circuit             2012  94.661
# 172  Silverstone Circuit             2013  93.401
# 192  Silverstone Circuit             2014  97.176
# 211  Silverstone Circuit             2015  97.093
# 231  Silverstone Circuit             2016  95.548
# 252  Silverstone Circuit             2017  90.621
# 272  Silverstone Circuit             2018  90.696
# 105  Suzuka Circuit                  2004  92.730
# 87   Suzuka Circuit                  2005  91.540
# 68   Suzuka Circuit                  2006  92.676
# 14   Suzuka Circuit                  2009  92.569
# 122  Suzuka Circuit                  2010  93.474
# 140  Suzuka Circuit                  2011  96.568
# 159  Suzuka Circuit                  2012  95.774
# 179  Suzuka Circuit                  2013  94.587
# 198  Suzuka Circuit                  2014  111.600
# 216  Suzuka Circuit                  2015  96.145
# 238  Suzuka Circuit                  2016  95.118
# 258  Suzuka Circuit                  2017  93.144
# 279  Suzuka Circuit                  2018  92.318
